# %%
import sys
print("Python:", sys.executable)
print("Версия:", sys.version)

import pandas as pd
print("Pandas:", pd.__version__)

print("\n✅ ВСЁ РАБОТАЕТ! Готов к Модулю 1!!!")
# Out:
# Python: c:\Users\User\AppData\Local\Programs\Python\Python314\python.exe
# Версия: 3.14.0 (tags/v3.14.0:ebf955d, Oct  7 2025, 10:15:03) [MSC v.1944 64 bit (AMD64)]
# Pandas: 2.3.3
#
# ✅ ВСЁ РАБОТАЕТ! Готов к Модулю 1!!!
